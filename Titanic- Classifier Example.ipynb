# %%
import keras
from keras.layers import Dense, Dropout, BatchNormalization, Activation
from keras.models import Sequential
from keras.utils import to_categorical
# Out:
# Using TensorFlow backend.

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
from matplotlib import pyplot
# %matplotlib inline

# %% [markdown]
# # 1. Let's import some data

# %% [markdown]
# https://www.kaggle.com/c/titanic/data

# %%
train_dataset=pd.DataFrame()
train_dataset=pd.read_csv('https://raw.githubusercontent.com/thousandoaks/AOMDeepLearningWorkshop/master/titanictrain.csv')

# %%
train_dataset.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %% [markdown]
# ### We want to predict Survived, using the following features: PClass, Sex, Age, SibSp, Parch, Fare, Embarked

# %% [markdown]
# ### We have to transform features Sex and Embarked (a.k.a label encoding)

# %%
train_dataset = train_dataset.replace(["male", "female"], [0,1])
train_dataset = train_dataset.replace(["S", "C", "Q"], [0,1,2])
train_dataset= train_dataset.fillna(0)

# %%
train_dataset.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
# 5                                   Moran, Mr. James    0   0.0      0      0
# 6                            McCarthy, Mr. Timothy J    0  54.0      0      0
# 7                     Palsson, Master. Gosta Leonard    0   2.0      3      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)    1  27.0      0      2
# 9                Nasser, Mrs. Nicholas (Adele Achem)    1  14.0      1      0
#
#              Ticket     Fare Cabin  Embarked
# 0         A/5 21171   7.2500     0       0.0
# 1          PC 17599  71.2833   C85       1.0
# 2  STON/O2. 3101282   7.9250     0       0.0
# 3            113803  53.1000  C123       0.0
# 4            373450   8.0500     0       0.0
# 5            330877   8.4583     0       2.0
# 6             17463  51.8625   E46       0.0
# 7            349909  21.0750     0       0.0
# 8            347742  11.1333     0       0.0
# 9            237736  30.0708     0       1.0

# %%
target = train_dataset[["Survived"]]
features = train_dataset[["Pclass","Sex","Age","SibSp","Parch","Fare","Embarked"]]

# %%
#convert to numpy array for NN
features = features.values
target = target.values

# %%
#target = to_categorical(train_dataset['Survived'])

# %%
target[0:10]
# Out:
# array([[0],
#        [1],
#        [1],
#        [1],
#        [0],
#        [0],
#        [0],
#        [0],
#        [1],
#        [1]])

# %%
features[0:10]
# Out:
# array([[  3.    ,   0.    ,  22.    ,   1.    ,   0.    ,   7.25  ,   0.    ],
#        [  1.    ,   1.    ,  38.    ,   1.    ,   0.    ,  71.2833,   1.    ],
#        [  3.    ,   1.    ,  26.    ,   0.    ,   0.    ,   7.925 ,   0.    ],
#        [  1.    ,   1.    ,  35.    ,   1.    ,   0.    ,  53.1   ,   0.    ],
#        [  3.    ,   0.    ,  35.    ,   0.    ,   0.    ,   8.05  ,   0.    ],
#        [  3.    ,   0.    ,   0.    ,   0.    ,   0.    ,   8.4583,   2.    ],
#        [  1.    ,   0.    ,  54.    ,   0.    ,   0.    ,  51.8625,   0.    ],
#        [  3.    ,   0.    ,   2.    ,   3.    ,   1.    ,  21.075 ,   0.    ],
#        [  3.    ,   1.    ,  27.    ,   0.    ,   2.    ,  11.1333,   0.    ],
#        [  2.    ,   1.    ,  14.    ,   1.    ,   0.    ,  30.0708,   1.    ]])

# %%
# we will only use the following features: PClass, Age, SibSp,Parch, Fare
#predictors=train_dataset[['Pclass','Sex','Age','SibSp','Parch','Fare']].values

# %%
#predictors

# %%
numberofcolumns=features.shape[1]
numberofcolumns
# Out:
# 7

# %% [markdown]
# ## 2. Let's understand the data

# %%
correlation_matrix=train_dataset.corr()
correlation_matrix
# Out:
#              PassengerId  Survived    Pclass       Sex       Age     SibSp  \
# PassengerId     1.000000 -0.005007 -0.035144 -0.042939  0.038125 -0.057527
# Survived       -0.005007  1.000000 -0.338481  0.543351  0.010539 -0.035322
# Pclass         -0.035144 -0.338481  1.000000 -0.131900 -0.361353  0.083081
# Sex            -0.042939  0.543351 -0.131900  1.000000 -0.024978  0.114631
# Age             0.038125  0.010539 -0.361353 -0.024978  1.000000 -0.184664
# SibSp          -0.057527 -0.035322  0.083081  0.114631 -0.184664  1.000000
# Parch          -0.001652  0.081629  0.018443  0.245489 -0.048786  0.414838
# Fare            0.012658  0.257307 -0.549500  0.182333  0.135516  0.159651
# Embarked       -0.030467  0.106811  0.045702  0.116569 -0.209388 -0.059961
#
#                 Parch      Fare  Embarked
# PassengerId -0.001652  0.012658 -0.030467
# Survived     0.081629  0.257307  0.106811
# Pclass       0.018443 -0.549500  0.045702
# Sex          0.245489  0.182333  0.116569
# Age         -0.048786  0.135516 -0.209388
# SibSp        0.414838  0.159651 -0.059961
# Parch        1.000000  0.216225 -0.078665
# Fare         0.216225  1.000000  0.062142
# Embarked    -0.078665  0.062142  1.000000

# %%
ax = sns.heatmap(correlation_matrix,linewidths=.5)

# %% [markdown]
# # 3. Specify the architecture of the model (very basic one)

# %%
# Set up the model
model = Sequential()

# Add the first layer
model.add(Dense(100,activation='relu',input_shape=(numberofcolumns,)))

# Add a second layer
model.add(Dense(100, activation='relu'))

# Add the output layer
model.add(Dense(1,activation='sigmoid'))

# %% [markdown]
# # 4. Let's compile the model

# %%
# Compile the model. Add accuracy as the metric to benchmark our model
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %% [markdown]
# # 5. Let's fit the model

# %%
# Fit the model. This time we keep 20% of our samples for test purposes
model_training=model.fit(features,target,verbose=2,epochs=100,validation_split=0.1)
# Out:
# Train on 801 samples, validate on 90 samples
# Epoch 1/100
#  - 0s - loss: 0.8969 - acc: 0.5830 - val_loss: 0.5313 - val_acc: 0.7667
# Epoch 2/100
#  - 0s - loss: 0.6581 - acc: 0.6604 - val_loss: 0.6410 - val_acc: 0.6222
# Epoch 3/100
#  - 0s - loss: 0.6376 - acc: 0.6629 - val_loss: 0.5891 - val_acc: 0.7111
# Epoch 4/100
#  - 0s - loss: 0.6418 - acc: 0.6779 - val_loss: 0.5370 - val_acc: 0.6889
# Epoch 5/100
#  - 0s - loss: 0.5961 - acc: 0.6929 - val_loss: 0.4976 - val_acc: 0.7778
# Epoch 6/100
#  - 0s - loss: 0.5745 - acc: 0.6991 - val_loss: 0.5186 - val_acc: 0.7556
# Epoch 7/100
#  - 0s - loss: 0.5632 - acc: 0.7291 - val_loss: 0.5242 - val_acc: 0.7222
# Epoch 8/100
#  - 0s - loss: 0.5886 - acc: 0.7179 - val_loss: 0.4642 - val_acc: 0.7444
# Epoch 9/100
#  - 0s - loss: 0.6232 - acc: 0.7328 - val_loss: 0.4693 - val_acc: 0.7667
# Epoch 10/100
#  - 0s - loss: 0.6153 - acc: 0.7366 - val_loss: 0.5827 - val_acc: 0.6556
# Epoch 11/100
#  - 0s - loss: 0.5318 - acc: 0.7503 - val_loss: 0.5105 - val_acc: 0.8000
# Epoch 12/100
#  - 0s - loss: 0.5004 - acc: 0.7678 - val_loss: 0.4319 - val_acc: 0.8444
# Epoch 13/100
#  - 0s - loss: 0.5041 - acc: 0.7865 - val_loss: 0.4425 - val_acc: 0.8111
# Epoch 14/100
#  - 0s - loss: 0.5128 - acc: 0.7615 - val_loss: 0.4517 - val_acc: 0.8000
# Epoch 15/100
#  - 0s - loss: 0.4790 - acc: 0.7803 - val_loss: 0.4642 - val_acc: 0.7444
# Epoch 16/100
#  - 0s - loss: 0.4963 - acc: 0.7678 - val_loss: 0.4467 - val_acc: 0.8111
# Epoch 17/100
#  - 0s - loss: 0.5198 - acc: 0.7541 - val_loss: 0.4761 - val_acc: 0.8000
# Epoch 18/100
#  - 0s - loss: 0.4732 - acc: 0.7903 - val_loss: 0.4338 - val_acc: 0.7889
# Epoch 19/100
#  - 0s - loss: 0.5012 - acc: 0.7890 - val_loss: 0.4807 - val_acc: 0.7111
# Epoch 20/100
#  - 0s - loss: 0.4819 - acc: 0.7853 - val_loss: 0.4141 - val_acc: 0.7889
# Epoch 21/100
#  - 0s - loss: 0.4876 - acc: 0.7703 - val_loss: 0.4425 - val_acc: 0.8000
# Epoch 22/100
#  - 0s - loss: 0.4647 - acc: 0.7915 - val_loss: 0.4760 - val_acc: 0.7667
# Epoch 23/100
#  - 0s - loss: 0.4709 - acc: 0.7903 - val_loss: 0.4273 - val_acc: 0.8333
# Epoch 24/100
#  - 0s - loss: 0.5544 - acc: 0.7728 - val_loss: 0.4837 - val_acc: 0.7444
# Epoch 25/100
#  - 0s - loss: 0.4866 - acc: 0.7715 - val_loss: 0.4276 - val_acc: 0.8222
# Epoch 26/100
#  - 0s - loss: 0.5062 - acc: 0.7815 - val_loss: 0.4656 - val_acc: 0.7889
# Epoch 27/100
#  - 0s - loss: 0.4842 - acc: 0.7915 - val_loss: 0.4457 - val_acc: 0.8111
# Epoch 28/100
#  - 0s - loss: 0.4875 - acc: 0.7878 - val_loss: 0.4356 - val_acc: 0.8000
# Epoch 29/100
#  - 0s - loss: 0.4488 - acc: 0.8015 - val_loss: 0.7653 - val_acc: 0.6778
# Epoch 30/100
#  - 0s - loss: 1.9192 - acc: 0.5880 - val_loss: 0.5063 - val_acc: 0.7556
# Epoch 31/100
#  - 0s - loss: 0.7047 - acc: 0.7453 - val_loss: 0.4496 - val_acc: 0.7889
# Epoch 32/100
#  - 0s - loss: 0.5968 - acc: 0.7566 - val_loss: 0.4447 - val_acc: 0.7889
# Epoch 33/100
#  - 0s - loss: 0.4696 - acc: 0.7890 - val_loss: 0.4316 - val_acc: 0.8111
# Epoch 34/100
#  - 0s - loss: 0.4815 - acc: 0.7803 - val_loss: 0.4895 - val_acc: 0.8111
# Epoch 35/100
#  - 0s - loss: 0.4962 - acc: 0.7765 - val_loss: 0.4308 - val_acc: 0.8333
# Epoch 36/100
#  - 0s - loss: 0.4596 - acc: 0.7878 - val_loss: 0.4519 - val_acc: 0.8111
# Epoch 37/100
#  - 0s - loss: 0.4488 - acc: 0.7953 - val_loss: 0.4198 - val_acc: 0.8222
# Epoch 38/100
#  - 0s - loss: 0.4552 - acc: 0.7815 - val_loss: 0.4510 - val_acc: 0.8000
# Epoch 39/100
#  - 0s - loss: 0.4738 - acc: 0.7940 - val_loss: 0.4735 - val_acc: 0.8222
# Epoch 40/100
#  - 0s - loss: 0.4486 - acc: 0.7915 - val_loss: 0.4384 - val_acc: 0.7778
# Epoch 41/100
#  - 0s - loss: 0.4650 - acc: 0.7865 - val_loss: 0.4470 - val_acc: 0.7889
# Epoch 42/100
#  - 0s - loss: 0.4407 - acc: 0.8052 - val_loss: 0.4173 - val_acc: 0.8222
# Epoch 43/100
#  - 0s - loss: 0.4475 - acc: 0.7953 - val_loss: 0.4237 - val_acc: 0.8333
# Epoch 44/100
#  - 0s - loss: 0.4417 - acc: 0.7890 - val_loss: 0.4202 - val_acc: 0.8111
# Epoch 45/100
#  - 0s - loss: 0.4408 - acc: 0.7978 - val_loss: 0.4473 - val_acc: 0.7889
# Epoch 46/100
#  - 0s - loss: 0.4442 - acc: 0.8027 - val_loss: 0.4379 - val_acc: 0.8000
# Epoch 47/100
#  - 0s - loss: 0.4438 - acc: 0.7903 - val_loss: 0.4237 - val_acc: 0.8222
# Epoch 48/100
#  - 0s - loss: 0.4400 - acc: 0.7915 - val_loss: 0.4318 - val_acc: 0.8222
# Epoch 49/100
#  - 0s - loss: 0.4421 - acc: 0.7940 - val_loss: 0.4325 - val_acc: 0.8333
# Epoch 50/100
#  - 0s - loss: 0.4732 - acc: 0.7865 - val_loss: 0.4363 - val_acc: 0.7889
# Epoch 51/100
#  - 0s - loss: 0.4453 - acc: 0.8002 - val_loss: 0.4739 - val_acc: 0.8333
# Epoch 52/100
#  - 0s - loss: 0.5219 - acc: 0.7740 - val_loss: 0.4429 - val_acc: 0.8333
# Epoch 53/100
#  - 0s - loss: 0.4805 - acc: 0.7740 - val_loss: 0.4370 - val_acc: 0.7889
# Epoch 54/100
#  - 0s - loss: 0.4448 - acc: 0.7965 - val_loss: 0.4427 - val_acc: 0.8000
# Epoch 55/100
#  - 0s - loss: 0.4321 - acc: 0.8027 - val_loss: 0.4421 - val_acc: 0.8000
# Epoch 56/100
#  - 0s - loss: 0.5178 - acc: 0.7665 - val_loss: 0.4323 - val_acc: 0.8000
# Epoch 57/100
#  - 0s - loss: 0.4424 - acc: 0.7903 - val_loss: 0.4524 - val_acc: 0.8000
# Epoch 58/100
#  - 0s - loss: 0.4462 - acc: 0.8052 - val_loss: 0.4312 - val_acc: 0.8000
# Epoch 59/100
#  - 0s - loss: 0.4364 - acc: 0.7990 - val_loss: 0.4560 - val_acc: 0.7889
# Epoch 60/100
#  - 0s - loss: 0.4432 - acc: 0.7965 - val_loss: 0.4340 - val_acc: 0.8333
# Epoch 61/100
#  - 0s - loss: 0.5242 - acc: 0.7728 - val_loss: 0.4214 - val_acc: 0.7889
# Epoch 62/100
#  - 0s - loss: 0.4701 - acc: 0.7890 - val_loss: 0.4257 - val_acc: 0.8333
# Epoch 63/100
#  - 0s - loss: 0.4389 - acc: 0.8027 - val_loss: 0.4271 - val_acc: 0.7889
# Epoch 64/100
#  - 0s - loss: 0.4240 - acc: 0.8065 - val_loss: 0.4194 - val_acc: 0.7889
# Epoch 65/100
#  - 0s - loss: 0.4282 - acc: 0.8115 - val_loss: 0.4198 - val_acc: 0.8222
# Epoch 66/100
#  - 0s - loss: 0.4365 - acc: 0.7990 - val_loss: 0.4424 - val_acc: 0.8000
# Epoch 67/100
#  - 0s - loss: 0.4818 - acc: 0.7853 - val_loss: 0.4270 - val_acc: 0.8222
# Epoch 68/100
#  - 0s - loss: 0.4377 - acc: 0.7940 - val_loss: 0.4615 - val_acc: 0.8000
# Epoch 69/100
#  - 0s - loss: 0.4461 - acc: 0.7953 - val_loss: 0.4320 - val_acc: 0.8111
# Epoch 70/100
#  - 0s - loss: 0.5430 - acc: 0.7665 - val_loss: 0.4622 - val_acc: 0.7889
# Epoch 71/100
#  - 0s - loss: 0.4503 - acc: 0.7903 - val_loss: 0.4379 - val_acc: 0.8222
# Epoch 72/100
#  - 0s - loss: 0.4601 - acc: 0.7878 - val_loss: 0.4430 - val_acc: 0.7889
# Epoch 73/100
#  - 0s - loss: 0.4386 - acc: 0.8015 - val_loss: 0.4163 - val_acc: 0.8111
# Epoch 74/100
#  - 0s - loss: 0.4261 - acc: 0.8115 - val_loss: 0.4267 - val_acc: 0.8222
# Epoch 75/100
#  - 0s - loss: 0.4227 - acc: 0.7990 - val_loss: 0.4233 - val_acc: 0.8222
# Epoch 76/100
#  - 0s - loss: 0.4160 - acc: 0.8077 - val_loss: 0.4192 - val_acc: 0.8222
# Epoch 77/100
#  - 0s - loss: 0.4224 - acc: 0.7965 - val_loss: 0.4167 - val_acc: 0.8222
# Epoch 78/100
#  - 0s - loss: 0.4525 - acc: 0.7953 - val_loss: 0.4636 - val_acc: 0.8000
# Epoch 79/100
#  - 0s - loss: 0.5081 - acc: 0.7753 - val_loss: 0.4196 - val_acc: 0.8333
# Epoch 80/100
#  - 0s - loss: 0.4581 - acc: 0.7965 - val_loss: 0.4520 - val_acc: 0.7778
# Epoch 81/100
#  - 0s - loss: 0.4295 - acc: 0.7990 - val_loss: 0.4278 - val_acc: 0.8111
# Epoch 82/100
#  - 0s - loss: 0.4421 - acc: 0.7953 - val_loss: 0.4475 - val_acc: 0.7889
# Epoch 83/100
#  - 0s - loss: 0.4298 - acc: 0.8002 - val_loss: 0.4504 - val_acc: 0.8111
# Epoch 84/100
#  - 0s - loss: 0.4826 - acc: 0.7803 - val_loss: 0.4110 - val_acc: 0.8333
# Epoch 85/100
#  - 0s - loss: 0.4549 - acc: 0.7928 - val_loss: 0.4516 - val_acc: 0.8000
# Epoch 86/100
#  - 0s - loss: 0.4407 - acc: 0.8165 - val_loss: 0.4379 - val_acc: 0.8000
# Epoch 87/100
#  - 0s - loss: 0.4180 - acc: 0.8140 - val_loss: 0.4422 - val_acc: 0.8333
# Epoch 88/100
#  - 0s - loss: 0.4602 - acc: 0.8052 - val_loss: 0.4351 - val_acc: 0.8222
# Epoch 89/100
#  - 0s - loss: 0.4254 - acc: 0.8027 - val_loss: 0.4217 - val_acc: 0.8111
# Epoch 90/100
#  - 0s - loss: 0.4132 - acc: 0.8065 - val_loss: 0.4209 - val_acc: 0.8000
# Epoch 91/100
#  - 0s - loss: 0.4230 - acc: 0.7990 - val_loss: 0.4294 - val_acc: 0.8000
# Epoch 92/100
#  - 0s - loss: 0.4414 - acc: 0.7965 - val_loss: 0.4398 - val_acc: 0.8333
# Epoch 93/100
#  - 0s - loss: 0.5462 - acc: 0.7765 - val_loss: 0.4448 - val_acc: 0.8000
# Epoch 94/100
#  - 0s - loss: 0.4617 - acc: 0.7853 - val_loss: 0.4327 - val_acc: 0.8000
# Epoch 95/100
#  - 0s - loss: 0.4146 - acc: 0.8090 - val_loss: 0.4219 - val_acc: 0.8333
# Epoch 96/100
#  - 0s - loss: 0.4116 - acc: 0.8102 - val_loss: 0.4820 - val_acc: 0.8111
# Epoch 97/100
#  - 0s - loss: 1.2343 - acc: 0.6891 - val_loss: 0.5648 - val_acc: 0.7444
# Epoch 98/100
#  - 0s - loss: 0.5428 - acc: 0.7753 - val_loss: 0.4275 - val_acc: 0.8111
# Epoch 99/100
#  - 0s - loss: 0.4657 - acc: 0.7965 - val_loss: 0.3962 - val_acc: 0.8111
# Epoch 100/100
#  - 0s - loss: 0.4598 - acc: 0.7903 - val_loss: 0.4043 - val_acc: 0.8222

# %% [markdown]
# # 6. Let's evaluate our model

# %%
# Create the plot
pyplot.plot(model_training.history['val_loss'], 'r')
pyplot.xlabel('Epochs')
pyplot.ylabel('Validation score')
pyplot.show()

# %% [markdown]
# # 7. Let's improve our model

# %%
# Set up the model
#model2 = Sequential()
# Add the first layer
#model2.add(Dense(100,activation='relu',input_shape=(numberofcolumns,)))
# Add a second layer


#model2.add(Dense(100, activation='relu'))
#model2.add(Dense(10, activation='relu'))

# Add the output layer
#model2.add(Dense(1,activation='sigmoid'))

# %%
model2 = Sequential()
#input layer
model2.add(Dense(100, input_shape=(numberofcolumns,)))
model2.add(BatchNormalization())
model2.add(Activation("relu"))
model2.add(Dropout(0.4))

# hidden layers
model2.add(Dense(50))
model2.add(BatchNormalization())
model2.add(Activation("sigmoid"))
model2.add(Dropout(0.4))
    
model2.add(Dense(10))
model2.add(BatchNormalization())
model2.add(Activation("sigmoid"))
model2.add(Dropout(0.4))
    
#model2.add(Dense(2, activation="sigmoid"))
    
# output layer
model2.add(Dense(1, activation='sigmoid'))

# %%
# Compile the model. Add accuracy as the metric to benchmark our model
model2.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
#Fit the model. This time we keep 20% of our samples for test purposes
model2_training=model2.fit(features,target,verbose=2,epochs=100,validation_split=0.1)
# Out:
# Train on 801 samples, validate on 90 samples
# Epoch 1/100
#  - 0s - loss: 0.8087 - acc: 0.4082 - val_loss: 0.7234 - val_acc: 0.3778
# Epoch 2/100
#  - 0s - loss: 0.7509 - acc: 0.4919 - val_loss: 0.6779 - val_acc: 0.5111
# Epoch 3/100
#  - 0s - loss: 0.7273 - acc: 0.5031 - val_loss: 0.6522 - val_acc: 0.7222
# Epoch 4/100
#  - 0s - loss: 0.6984 - acc: 0.5431 - val_loss: 0.6372 - val_acc: 0.6889
# Epoch 5/100
#  - 0s - loss: 0.6745 - acc: 0.5955 - val_loss: 0.6236 - val_acc: 0.7222
# Epoch 6/100
#  - 0s - loss: 0.6630 - acc: 0.6130 - val_loss: 0.6140 - val_acc: 0.7000
# Epoch 7/100
#  - 0s - loss: 0.6534 - acc: 0.5980 - val_loss: 0.6046 - val_acc: 0.6778
# Epoch 8/100
#  - 0s - loss: 0.6446 - acc: 0.6467 - val_loss: 0.5973 - val_acc: 0.7222
# Epoch 9/100
#  - 0s - loss: 0.6339 - acc: 0.6242 - val_loss: 0.5881 - val_acc: 0.7333
# Epoch 10/100
#  - 0s - loss: 0.6297 - acc: 0.6567 - val_loss: 0.5805 - val_acc: 0.7444
# Epoch 11/100
#  - 0s - loss: 0.6211 - acc: 0.6604 - val_loss: 0.5733 - val_acc: 0.7556
# Epoch 12/100
#  - 0s - loss: 0.6023 - acc: 0.6941 - val_loss: 0.5649 - val_acc: 0.7556
# Epoch 13/100
#  - 0s - loss: 0.5980 - acc: 0.6866 - val_loss: 0.5517 - val_acc: 0.7778
# Epoch 14/100
#  - 0s - loss: 0.6071 - acc: 0.6891 - val_loss: 0.5463 - val_acc: 0.7444
# Epoch 15/100
#  - 0s - loss: 0.5806 - acc: 0.7154 - val_loss: 0.5236 - val_acc: 0.7889
# Epoch 16/100
#  - 0s - loss: 0.5752 - acc: 0.7154 - val_loss: 0.5139 - val_acc: 0.8222
# Epoch 17/100
#  - 0s - loss: 0.5838 - acc: 0.7104 - val_loss: 0.5137 - val_acc: 0.7778
# Epoch 18/100
#  - 0s - loss: 0.5781 - acc: 0.7191 - val_loss: 0.5041 - val_acc: 0.8111
# Epoch 19/100
#  - 0s - loss: 0.5596 - acc: 0.7216 - val_loss: 0.4960 - val_acc: 0.8222
# Epoch 20/100
#  - 0s - loss: 0.5784 - acc: 0.6891 - val_loss: 0.5024 - val_acc: 0.7889
# Epoch 21/100
#  - 0s - loss: 0.5760 - acc: 0.7041 - val_loss: 0.4972 - val_acc: 0.8000
# Epoch 22/100
#  - 0s - loss: 0.5711 - acc: 0.7016 - val_loss: 0.5077 - val_acc: 0.8222
# Epoch 23/100
#  - 0s - loss: 0.5656 - acc: 0.7278 - val_loss: 0.4787 - val_acc: 0.8111
# Epoch 24/100
#  - 0s - loss: 0.5677 - acc: 0.7228 - val_loss: 0.4685 - val_acc: 0.8222
# Epoch 25/100
#  - 0s - loss: 0.5567 - acc: 0.7253 - val_loss: 0.4736 - val_acc: 0.7889
# Epoch 26/100
#  - 0s - loss: 0.5474 - acc: 0.7578 - val_loss: 0.4816 - val_acc: 0.8111
# Epoch 27/100
#  - 0s - loss: 0.5418 - acc: 0.7416 - val_loss: 0.4644 - val_acc: 0.8111
# Epoch 28/100
#  - 0s - loss: 0.5491 - acc: 0.7516 - val_loss: 0.4717 - val_acc: 0.8000
# Epoch 29/100
#  - 0s - loss: 0.5597 - acc: 0.7266 - val_loss: 0.4620 - val_acc: 0.8000
# Epoch 30/100
#  - 0s - loss: 0.5410 - acc: 0.7541 - val_loss: 0.4591 - val_acc: 0.8111
# Epoch 31/100
#  - 0s - loss: 0.5301 - acc: 0.7703 - val_loss: 0.4507 - val_acc: 0.8222
# Epoch 32/100
#  - 0s - loss: 0.5398 - acc: 0.7491 - val_loss: 0.4561 - val_acc: 0.8222
# Epoch 33/100
#  - 0s - loss: 0.5489 - acc: 0.7503 - val_loss: 0.4633 - val_acc: 0.8000
# Epoch 34/100
#  - 0s - loss: 0.5478 - acc: 0.7503 - val_loss: 0.4482 - val_acc: 0.8333
# Epoch 35/100
#  - 0s - loss: 0.5357 - acc: 0.7528 - val_loss: 0.4444 - val_acc: 0.8222
# Epoch 36/100
#  - 0s - loss: 0.5176 - acc: 0.7603 - val_loss: 0.4565 - val_acc: 0.8000
# Epoch 37/100
#  - 0s - loss: 0.5177 - acc: 0.7516 - val_loss: 0.4471 - val_acc: 0.8222
# Epoch 38/100
#  - 0s - loss: 0.5195 - acc: 0.7765 - val_loss: 0.4411 - val_acc: 0.8222
# Epoch 39/100
#  - 0s - loss: 0.5200 - acc: 0.7740 - val_loss: 0.4349 - val_acc: 0.8222
# Epoch 40/100
#  - 0s - loss: 0.5227 - acc: 0.7653 - val_loss: 0.4375 - val_acc: 0.8222
# Epoch 41/100
#  - 0s - loss: 0.5027 - acc: 0.7878 - val_loss: 0.4447 - val_acc: 0.8111
# Epoch 42/100
#  - 0s - loss: 0.5146 - acc: 0.7628 - val_loss: 0.4342 - val_acc: 0.8333
# Epoch 43/100
#  - 0s - loss: 0.5198 - acc: 0.7541 - val_loss: 0.4434 - val_acc: 0.8333
# Epoch 44/100
#  - 0s - loss: 0.5210 - acc: 0.7615 - val_loss: 0.4398 - val_acc: 0.8333
# Epoch 45/100
#  - 0s - loss: 0.5324 - acc: 0.7578 - val_loss: 0.4511 - val_acc: 0.8000
# Epoch 46/100
#  - 0s - loss: 0.5269 - acc: 0.7553 - val_loss: 0.4282 - val_acc: 0.8333
# Epoch 47/100
#  - 0s - loss: 0.5280 - acc: 0.7665 - val_loss: 0.4323 - val_acc: 0.8222
# Epoch 48/100
#  - 0s - loss: 0.5098 - acc: 0.7890 - val_loss: 0.4320 - val_acc: 0.8222
# Epoch 49/100
#  - 0s - loss: 0.5108 - acc: 0.7628 - val_loss: 0.4249 - val_acc: 0.8222
# Epoch 50/100
#  - 0s - loss: 0.5205 - acc: 0.7615 - val_loss: 0.4296 - val_acc: 0.8222
# Epoch 51/100
#  - 0s - loss: 0.5312 - acc: 0.7566 - val_loss: 0.4261 - val_acc: 0.8111
# Epoch 52/100
#  - 0s - loss: 0.5141 - acc: 0.7803 - val_loss: 0.4250 - val_acc: 0.8333
# Epoch 53/100
#  - 0s - loss: 0.5035 - acc: 0.7740 - val_loss: 0.4271 - val_acc: 0.8111
# Epoch 54/100
#  - 0s - loss: 0.5074 - acc: 0.7853 - val_loss: 0.4317 - val_acc: 0.8111
# Epoch 55/100
#  - 0s - loss: 0.5286 - acc: 0.7690 - val_loss: 0.4204 - val_acc: 0.8111
# Epoch 56/100
#  - 0s - loss: 0.5176 - acc: 0.7678 - val_loss: 0.4306 - val_acc: 0.8111
# Epoch 57/100
#  - 0s - loss: 0.4911 - acc: 0.7915 - val_loss: 0.4195 - val_acc: 0.8222
# Epoch 58/100
#  - 0s - loss: 0.5124 - acc: 0.7628 - val_loss: 0.4163 - val_acc: 0.8333
# Epoch 59/100
#  - 0s - loss: 0.5201 - acc: 0.7790 - val_loss: 0.4146 - val_acc: 0.8333
# Epoch 60/100
#  - 0s - loss: 0.5208 - acc: 0.7803 - val_loss: 0.4215 - val_acc: 0.8111
# Epoch 61/100
#  - 0s - loss: 0.5054 - acc: 0.7903 - val_loss: 0.4180 - val_acc: 0.8222
# Epoch 62/100
#  - 0s - loss: 0.5142 - acc: 0.7878 - val_loss: 0.4162 - val_acc: 0.8333
# Epoch 63/100
#  - 0s - loss: 0.5212 - acc: 0.7653 - val_loss: 0.4151 - val_acc: 0.8222
# Epoch 64/100
#  - 0s - loss: 0.5054 - acc: 0.7815 - val_loss: 0.4243 - val_acc: 0.8000
# Epoch 65/100
#  - 0s - loss: 0.5014 - acc: 0.7815 - val_loss: 0.4133 - val_acc: 0.8222
# Epoch 66/100
#  - 0s - loss: 0.5002 - acc: 0.7803 - val_loss: 0.4120 - val_acc: 0.8333
# Epoch 67/100
#  - 0s - loss: 0.4949 - acc: 0.7803 - val_loss: 0.4190 - val_acc: 0.8222
# Epoch 68/100
#  - 0s - loss: 0.4822 - acc: 0.7928 - val_loss: 0.4188 - val_acc: 0.8111
# Epoch 69/100
#  - 0s - loss: 0.4973 - acc: 0.7828 - val_loss: 0.4105 - val_acc: 0.8333
# Epoch 70/100
#  - 0s - loss: 0.5011 - acc: 0.8065 - val_loss: 0.4142 - val_acc: 0.8222
# Epoch 71/100
#  - 0s - loss: 0.4839 - acc: 0.7928 - val_loss: 0.4093 - val_acc: 0.8222
# Epoch 72/100
#  - 0s - loss: 0.5014 - acc: 0.7703 - val_loss: 0.4189 - val_acc: 0.8222
# Epoch 73/100
#  - 0s - loss: 0.5037 - acc: 0.7790 - val_loss: 0.4076 - val_acc: 0.8222
# Epoch 74/100
#  - 0s - loss: 0.5017 - acc: 0.7815 - val_loss: 0.4085 - val_acc: 0.8333
# Epoch 75/100
#  - 0s - loss: 0.4980 - acc: 0.7815 - val_loss: 0.4190 - val_acc: 0.8222
# Epoch 76/100
#  - 0s - loss: 0.5171 - acc: 0.7765 - val_loss: 0.4124 - val_acc: 0.8222
# Epoch 77/100
#  - 0s - loss: 0.4835 - acc: 0.7940 - val_loss: 0.4190 - val_acc: 0.8222
# Epoch 78/100
#  - 0s - loss: 0.4975 - acc: 0.7928 - val_loss: 0.4076 - val_acc: 0.8222
# Epoch 79/100
#  - 0s - loss: 0.4817 - acc: 0.7840 - val_loss: 0.4048 - val_acc: 0.8222
# Epoch 80/100
#  - 0s - loss: 0.4911 - acc: 0.7978 - val_loss: 0.4065 - val_acc: 0.8222
# Epoch 81/100
#  - 0s - loss: 0.5135 - acc: 0.7753 - val_loss: 0.4087 - val_acc: 0.8222
# Epoch 82/100
#  - 0s - loss: 0.5019 - acc: 0.7865 - val_loss: 0.4102 - val_acc: 0.8222
# Epoch 83/100
#  - 0s - loss: 0.4843 - acc: 0.7915 - val_loss: 0.4162 - val_acc: 0.8222
# Epoch 84/100
#  - 0s - loss: 0.4940 - acc: 0.7853 - val_loss: 0.4129 - val_acc: 0.8222
# Epoch 85/100
#  - 0s - loss: 0.4871 - acc: 0.7903 - val_loss: 0.4084 - val_acc: 0.8222
# Epoch 86/100
#  - 0s - loss: 0.5187 - acc: 0.7815 - val_loss: 0.3984 - val_acc: 0.8222
# Epoch 87/100
#  - 0s - loss: 0.4929 - acc: 0.7853 - val_loss: 0.3982 - val_acc: 0.8222
# Epoch 88/100
#  - 0s - loss: 0.4880 - acc: 0.8040 - val_loss: 0.4019 - val_acc: 0.8222
# Epoch 89/100
#  - 0s - loss: 0.4823 - acc: 0.7890 - val_loss: 0.4038 - val_acc: 0.8222
# Epoch 90/100
#  - 0s - loss: 0.5403 - acc: 0.7753 - val_loss: 0.4019 - val_acc: 0.8222
# Epoch 91/100
#  - 0s - loss: 0.4980 - acc: 0.7815 - val_loss: 0.3975 - val_acc: 0.8222
# Epoch 92/100
#  - 0s - loss: 0.5042 - acc: 0.7865 - val_loss: 0.3969 - val_acc: 0.8333
# Epoch 93/100
#  - 0s - loss: 0.4916 - acc: 0.7940 - val_loss: 0.3919 - val_acc: 0.8444
# Epoch 94/100
#  - 0s - loss: 0.4860 - acc: 0.7990 - val_loss: 0.4015 - val_acc: 0.8222
# Epoch 95/100
#  - 0s - loss: 0.4860 - acc: 0.8002 - val_loss: 0.3999 - val_acc: 0.8222
# Epoch 96/100
#  - 0s - loss: 0.4916 - acc: 0.7865 - val_loss: 0.4052 - val_acc: 0.8222
# Epoch 97/100
#  - 0s - loss: 0.4873 - acc: 0.7865 - val_loss: 0.4122 - val_acc: 0.8333
# Epoch 98/100
#  - 0s - loss: 0.4808 - acc: 0.7978 - val_loss: 0.3968 - val_acc: 0.8111
# Epoch 99/100
#  - 0s - loss: 0.5071 - acc: 0.7953 - val_loss: 0.3991 - val_acc: 0.8222
# Epoch 100/100
#  - 0s - loss: 0.4977 - acc: 0.7790 - val_loss: 0.4041 - val_acc: 0.8111

# %%
# Create the plot
pyplot.plot(model2_training.history['val_loss'], 'r',label='performance model 2 on test data')
pyplot.plot(model_training.history['val_loss'], 'b',label='performance model 1 on test data')
pyplot.xlabel('Epochs')
pyplot.ylabel('Validation score')
pyplot.legend()
pyplot.show()

# %% [markdown]
# ## Model 2 seems to be performing better in the long run

# %% [markdown]
# ## How is model 2 performing ?

# %%
train_dataset['Predicted']=pd.DataFrame(model2.predict(features))
# we transform probabilities into discrete outcomes (0/1)
train_dataset['Predicted_Discrete']=round(train_dataset['Predicted'])

# %%
# Create confusion matrix


confusion_matrix=pd.crosstab(train_dataset['Survived'], train_dataset['Predicted_Discrete'], rownames=['Actual Types'], colnames=['Predicted Types'])
confusion_matrix
# Out:
# Predicted Types  0.0  1.0
# Actual Types
# 0                506   43
# 1                112  230

# %% [markdown]
# ### We observe that model 2 is relatively good at predicting who will perish.
# ### Moreover model 2 achieves 83% of accuracy (is it good enough ?)

# %% [markdown]
# ### However model 2 predicted many survivors which did not survive in practice (62).
# ### Model 2 predicted many fatalities which did survive in practice (98).
#
# #### This gives us some hints for further improvement. Manual Analysis of misclassifications to understand the causes.

# %%
train_dataset.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
# 5                                   Moran, Mr. James    0   0.0      0      0
# 6                            McCarthy, Mr. Timothy J    0  54.0      0      0
# 7                     Palsson, Master. Gosta Leonard    0   2.0      3      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)    1  27.0      0      2
# 9                Nasser, Mrs. Nicholas (Adele Achem)    1  14.0      1      0
#
#              Ticket     Fare Cabin  Embarked  Predicted  Predicted_Discrete
# 0         A/5 21171   7.2500     0       0.0   0.127931                 0.0
# 1          PC 17599  71.2833   C85       1.0   0.810513                 1.0
# 2  STON/O2. 3101282   7.9250     0       0.0   0.535150                 1.0
# 3            113803  53.1000  C123       0.0   0.809539                 1.0
# 4            373450   8.0500     0       0.0   0.117135                 0.0
# 5            330877   8.4583     0       2.0   0.140352                 0.0
# 6             17463  51.8625   E46       0.0   0.191697                 0.0
# 7            349909  21.0750     0       0.0   0.152771                 0.0
# 8            347742  11.1333     0       0.0   0.483307                 0.0
# 9            237736  30.0708     0       1.0   0.786251                 1.0
